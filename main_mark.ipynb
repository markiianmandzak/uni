# %%
# !pip install pandas
# !pip install --upgrade pandas pyarrow

# %%
import pandas as pd

# %%
taxonomy = pd.read_parquet("data/feature-normalization-hackathon/data/taxonomy/taxonomy.parquet")
train_gt = pd.read_parquet("data/feature-normalization-hackathon/data/test/products.parquet")
train_products = pd.read_parquet("data/feature-normalization-hackathon/data/test/submission.parquet")
val_gt = pd.read_parquet("data/feature-normalization-hackathon/data/val/product_features.parquet")
val_products = pd.read_parquet("data/feature-normalization-hackathon/data/val/products.parquet")
test_products = pd.read_parquet("data/feature-normalization-hackathon/data/test/products.parquet")
test_submission = pd.read_parquet("data/feature-normalization-hackathon/data/test/submission.parquet")

# %%
taxonomy['feature_type'].unique()
# Out:
# <ArrowStringArray>
# ['numeric', 'categorical']
# Length: 2, dtype: str

# %%
taxonomy
# Out:
#              category    feature_name  \
# 0             iso7094         Außen-Ø
# 1             iso7094         Innen-Ø
# 2             iso7094        Material
# 3             iso7094      Oberfläche
# 4             iso7094          Stärke
# ...               ...             ...
# 65761  tiefkuehlzelle      Isolierung
# 65762  tiefkuehlzelle            Maße
# 65763  tieflochbohrer          Nenn-Ø
# 65764  tieflochbohrer  Spannutenlänge
# 65765  tieflochbohrer    Schneidstoff
#
#                                aggregated_feature_values feature_type
# 0      {'[80 mm]','[105 mm]','[44 mm]','[98 mm]','[56...      numeric
# 1      {'[13.5 mm]','[11 mm]','[15.5 mm]','[22 mm]','...      numeric
# 2      {'[Stahl]','[Edelstahl (A2)]','[Edelstahl (A4)...  categorical
# 3      {'[galvanisch verzinkt]','[blank]','[feuerverz...  categorical
# 4      {'[6 mm]','[3 mm]','[4 mm]','[2 mm]','[5 mm]',...      numeric
# ...                                                  ...          ...
# ...

# %%
train
# Out:
#                                            uid feature_name  \
# 0             B2887-228998_|_sicherheitsascher     Material
# 1        B7409-2757653-BP_|_modellauto_chassis      Maßstab
# 2            B9113-ROLINE 11045511_|_dvi_kabel  Pinbelegung
# 3            B9113-ROLINE 11045511_|_dvi_kabel        Länge
# 4                    B8TFE-4229198_|_dvi_kabel  Pinbelegung
# ...                                        ...          ...
# 8664587     B7094-2595816-BP_|_gerade_pinzette        Länge
# 8664588     B7094-2595816-BP_|_gerade_pinzette  Fassmaultyp
# 8664640          139-2768638_|_gerade_pinzette        Länge
# 8664641          139-2768638_|_gerade_pinzette  Fassmaultyp
# 8664645       262A-10298091_|_uebergangsstueck     Material
#
#                   feature_value feature_type
# 0                         Stahl  categorical
# 1                           :10      numeric
# 2        DVI-D 24+1 (Dual-Link)  categorical
# 3                           1 m      numeric
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 6.2 MB/s  0:00:01 eta 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 5.2 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 10.2 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
train_product_features['description'].str.len().hist(bins=100)
# Out:
# <Axes: >

# %%
train_product_features['description'].str.len().sum()/3_103_602*200_000_000
# Out:
# np.float64(118159237685.75996)

# %%
118_159_237_685
